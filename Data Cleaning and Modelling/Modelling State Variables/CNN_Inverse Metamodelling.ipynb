# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
import keras
from keras import Sequential
from keras import models
from keras import layers
from keras.layers import Dropout
from keras.models import Sequential
import tensorflow as tf
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras.regularizers import l1
from keras.layers import Dense
from keras.utils.vis_utils import plot_model

from keras import regularizers

# %%
Total_Y_data = pd.read_csv("X_data.csv")
Total_X_data = pd.read_csv("Y_data_voltage.csv")

Total_Y_data.drop("Unnamed: 0", axis=1, inplace=True)
Total_X_data.drop("Unnamed: 0", axis=1, inplace=True)

# %%
Total_Y_data
# Out:
#         V_myo(um3)    V_SR(um3)  V_myo_uL(uL)  V_SR_uL(uL)  i_NaK_max(uA)  \
# 0     18087.633040  2971.250703      0.000033     0.000003       0.000103
# 1     35119.155518  2546.504451      0.000024     0.000001       0.000080
# 2     31723.880665  1163.450863      0.000018     0.000002       0.000052
# 3     17885.692846  3043.770618      0.000022     0.000003       0.000125
# 4     30331.086522  2278.322744      0.000038     0.000003       0.000069
# ...            ...          ...           ...          ...            ...
# 5339  29686.697458  1051.560825      0.000032     0.000003       0.000137
# 5340  14571.354624  1386.516522      0.000020     0.000001       0.000096
# 5341  32437.538891  2095.063478      0.000022     0.000003       0.000092
# 5342  28460.428755  2809.654831      0.000015     0.000002       0.000115
# 5343  20844.507477  1537.242389      0.000037     0.000001       0.000126
#
#       K_m_K(mM)  K_m_Na(mM)  K_o(millimolar)  Na_o(millimolar)  \
# 0      1.634672    8.457044         6.694638        184.384591
# 1      1.266706    7.810010         3.160808        112.247246
# 2      1.955174    9.439872         3.730495        149.609915
# 3      0.971169    6.645655         4.763852         74.651845
# 4      1.539212    9.291735         2.934818        167.996222
# ...         ...         ...              ...               ...
# 5339   1.545477   12.402027         4.349500        168.432829
# 5340   1.321781    7.314302         5.223747        146.514228
# 5341   1.545330    8.810272         7.539690        207.497693
# 5342   1.331515    9.105736         7.301446        132.468385
# 5343   1.638435    6.636080         7.940330         89.936050
#
#       Ca_TRPN_Max(mM)  ...  tau_R(ms)     phi_R   theta_R  K_RyR(mM)  \
# 0            0.083447  ...   2.491605  0.069589  0.008294   0.029984
# 1            0.101991  ...   1.776488  0.073601  0.010835   0.037541
# 2            0.088179  ...   3.528071  0.074748  0.007420   0.058981
# 3            0.069008  ...   1.640167  0.068951  0.009030   0.042338
# 4            0.103373  ...   1.859182  0.054088  0.007173   0.056029
# ...               ...  ...        ...       ...       ...        ...
# 5339         0.093633  ...   3.196147  0.069653  0.008720   0.025202
# 5340         0.091678  ...   2.427242  0.070424  0.009969   0.055870
# 5341         0.068950  ...   3.502983  0.052886  0.009852   0.023352
# 5342         0.087496  ...   1.643484  0.057020  0.008370   0.027257
# 5343         0.092497  ...   2.324241  0.056590  0.009668   0.028554
#
#        K_L(mM)         a          b         c           d  tau_s_ss
# 0     0.000162  0.085792  19.130331  0.012273  123.013407  2.363106
# 1     0.000160  0.069981  17.626720  0.009399   76.115827  2.312663
# 2     0.000150  0.067458  11.149554  0.011840   87.480619  2.113083
# 3     0.000288  0.093335   9.438720  0.013712   72.067875  2.977916
# 4     0.000117  0.084184  20.728823  0.008027  102.415199  2.053384
# ...        ...       ...        ...       ...         ...       ...
# 5339  0.000140  0.037697  11.516852  0.014368  139.310956  3.084144
# 5340  0.000264  0.073526  12.098269  0.014361  110.857333  1.108004
# 5341  0.000201  0.062598  19.120915  0.012294   77.995824  2.526280
# 5342  0.000214  0.043176  18.504241  0.013315   55.964035  1.410034
# 5343  0.000241  0.061049  15.613426  0.009141  131.972930  1.372408
#
# [5344 rows x 76 columns]

# %%
#Total_Y_data = Total_Y_data.iloc[:, [0, 2, 3, 4, 5, 6, 7, 8, 9, 11, 12, 13, 14, 15, 16, 18, 19, 22, 23, 24, 25, 26, 27, 28, 29, 31, 32, 33, 34, 36, 38, 39, 40, 41, 42, 49, 55, 56, 57, 61, 62, 63, 64, 65, 67, 68, 69, 70, 75]]

# %%
# Total_Y_data = Total_Y_data[['V_myo(um3)',
#   'N',
# 'g_D(um3_per_ms)',
# 'K_L(mM)',

# 'V_myo_uL(uL)',
#   'del_VL(mV)',
# 'tau_L(ms)',
# 'phi_L',
# 'g_t(microS)',
# 'K_RyR(mM)']]

# %%
Total_Y_data
# Out:
#         V_myo(um3)    V_SR(um3)  V_myo_uL(uL)  V_SR_uL(uL)  i_NaK_max(uA)  \
# 0     18087.633040  2971.250703      0.000033     0.000003       0.000103
# 1     35119.155518  2546.504451      0.000024     0.000001       0.000080
# 2     31723.880665  1163.450863      0.000018     0.000002       0.000052
# 3     17885.692846  3043.770618      0.000022     0.000003       0.000125
# 4     30331.086522  2278.322744      0.000038     0.000003       0.000069
# ...            ...          ...           ...          ...            ...
# 5339  29686.697458  1051.560825      0.000032     0.000003       0.000137
# 5340  14571.354624  1386.516522      0.000020     0.000001       0.000096
# 5341  32437.538891  2095.063478      0.000022     0.000003       0.000092
# 5342  28460.428755  2809.654831      0.000015     0.000002       0.000115
# 5343  20844.507477  1537.242389      0.000037     0.000001       0.000126
#
#       K_m_K(mM)  K_m_Na(mM)  K_o(millimolar)  Na_o(millimolar)  \
# 0      1.634672    8.457044         6.694638        184.384591
# 1      1.266706    7.810010         3.160808        112.247246
# 2      1.955174    9.439872         3.730495        149.609915
# 3      0.971169    6.645655         4.763852         74.651845
# 4      1.539212    9.291735         2.934818        167.996222
# ...         ...         ...              ...               ...
# 5339   1.545477   12.402027         4.349500        168.432829
# 5340   1.321781    7.314302         5.223747        146.514228
# 5341   1.545330    8.810272         7.539690        207.497693
# 5342   1.331515    9.105736         7.301446        132.468385
# 5343   1.638435    6.636080         7.940330         89.936050
#
#       Ca_TRPN_Max(mM)  ...  tau_R(ms)     phi_R   theta_R  K_RyR(mM)  \
# 0            0.083447  ...   2.491605  0.069589  0.008294   0.029984
# 1            0.101991  ...   1.776488  0.073601  0.010835   0.037541
# 2            0.088179  ...   3.528071  0.074748  0.007420   0.058981
# 3            0.069008  ...   1.640167  0.068951  0.009030   0.042338
# 4            0.103373  ...   1.859182  0.054088  0.007173   0.056029
# ...               ...  ...        ...       ...       ...        ...
# 5339         0.093633  ...   3.196147  0.069653  0.008720   0.025202
# 5340         0.091678  ...   2.427242  0.070424  0.009969   0.055870
# 5341         0.068950  ...   3.502983  0.052886  0.009852   0.023352
# 5342         0.087496  ...   1.643484  0.057020  0.008370   0.027257
# 5343         0.092497  ...   2.324241  0.056590  0.009668   0.028554
#
#        K_L(mM)         a          b         c           d  tau_s_ss
# 0     0.000162  0.085792  19.130331  0.012273  123.013407  2.363106
# 1     0.000160  0.069981  17.626720  0.009399   76.115827  2.312663
# 2     0.000150  0.067458  11.149554  0.011840   87.480619  2.113083
# 3     0.000288  0.093335   9.438720  0.013712   72.067875  2.977916
# 4     0.000117  0.084184  20.728823  0.008027  102.415199  2.053384
# ...        ...       ...        ...       ...         ...       ...
# 5339  0.000140  0.037697  11.516852  0.014368  139.310956  3.084144
# 5340  0.000264  0.073526  12.098269  0.014361  110.857333  1.108004
# 5341  0.000201  0.062598  19.120915  0.012294   77.995824  2.526280
# 5342  0.000214  0.043176  18.504241  0.013315   55.964035  1.410034
# 5343  0.000241  0.061049  15.613426  0.009141  131.972930  1.372408
#
# [5344 rows x 76 columns]

# %%
Total_X_data
# Out:
#              0          1          2          3          4          5  \
# 0    -80.50146 -73.620314 -67.357399 -61.382787 -54.541782  17.816059
# 1    -80.50146 -74.765668 -68.713439 -62.584872 -55.838068 -25.933030
# 2    -80.50146 -75.313260 -70.198321 -65.071257 -59.815601 -53.775142
# 3    -80.50146 -75.194863 -70.074919 -64.978059 -59.594462 -51.542387
# 4    -80.50146 -74.804201 -68.759999 -62.434073 -55.279696  -8.992941
# ...        ...        ...        ...        ...        ...        ...
# 5339 -80.50146 -74.539389 -68.691773 -62.852965 -56.732048 -46.819963
# 5340 -80.50146 -74.946544 -69.958875 -65.247660 -60.515719 -54.716446
# 5341 -80.50146 -73.774451 -67.736315 -62.082204 -56.215736 -42.959873
# 5342 -80.50146 -73.900027 -68.270301 -63.185353 -58.049697 -48.268372
# 5343 -80.50146 -73.378675 -67.225861 -61.546816 -55.432824 -34.730714
#
#               6          7          8          9  ...        240        241  \
# 0     58.881427  53.758364  47.125866  41.577130  ...   8.093526  14.233536
# 1     46.183495  38.722102  28.631157  21.391622  ... -20.079739 -20.281990
# 2    -34.425259  34.122383  34.104529  26.182478  ... -86.948376 -86.950726
# 3     37.589030  41.796535  34.684865  28.438937  ...  -3.277842  -3.286780
# 4     57.832149  56.728695  53.429818  50.690608  ... -72.233335 -72.637223
# ...         ...        ...        ...        ...  ...        ...        ...
# 5339  34.833818  42.798500  37.444791  31.481640  ...  -4.694849  -4.892568
# 5340  -3.932562  52.140596  43.166902  34.589082  ... -79.789095 -79.794977
# 5341  46.504127  46.796831  37.706860  28.899318  ... -70.698642 -70.698645
# 5342  51.742084  53.797265  48.394088  42.877236  ... -73.107995 -73.117567
# 5343  39.336463  36.646365  29.345012  23.334629  ... -69.269274 -69.271532
#
#             242        243        244        245        246        247  \
# 0     17.883338  19.989153  21.158979  21.758281  22.005953  22.033896
# 1    -20.482540 -20.681184 -20.877728 -21.071989 -21.263794 -21.452982
# 2    -86.953046 -86.955339 -86.957603 -86.959839 -86.962048 -86.964230
# 3     -3.295097  -3.302810  -3.309936  -3.316489  -3.322486  -3.327945
# 4    -73.041176 -73.444834 -73.847821 -74.249752 -74.650228 -75.048845
# ...         ...        ...        ...        ...        ...        ...
# 5339  -5.092432  -5.294485  -5.498762  -5.705294  -5.914104  -6.125207
# 5340 -79.800800 -79.806565 -79.812273 -79.817925 -79.823521 -79.829062
# 5341 -70.698648 -70.698650 -70.698653 -70.698654 -70.698656 -70.698657
# 5342 -73.127077 -73.136526 -73.145914 -73.155241 -73.164507 -73.173711
# 5343 -69.273764 -69.275970 -69.278151 -69.280307 -69.282439 -69.284546
#
#             248        249
# 0     21.922441  21.721304
# 1    -21.639399 -21.822900
# 2    -86.966386 -86.968515
# 3     -3.332881  -3.337310
# 4    -75.445191 -75.838848
# ...         ...        ...
# 5339  -6.338606  -6.554296
# 5340 -79.834550 -79.839984
# 5341 -70.698658 -70.698658
# 5342 -73.182853 -73.191934
# 5343 -69.286629 -69.288688
#
# [5344 rows x 250 columns]

# %%
Y_test = Total_Y_data[:1068]
X_test = Total_X_data[:1068]

# %%
Y_data = Total_Y_data[1068:]
X_data = Total_X_data[1068:]

# %%
X_data.shape
# Out:
# (4276, 250)

# %%
Total_X_data
# Out:
#              0          1          2          3          4          5  \
# 0    -80.50146 -73.620314 -67.357399 -61.382787 -54.541782  17.816059
# 1    -80.50146 -74.765668 -68.713439 -62.584872 -55.838068 -25.933030
# 2    -80.50146 -75.313260 -70.198321 -65.071257 -59.815601 -53.775142
# 3    -80.50146 -75.194863 -70.074919 -64.978059 -59.594462 -51.542387
# 4    -80.50146 -74.804201 -68.759999 -62.434073 -55.279696  -8.992941
# ...        ...        ...        ...        ...        ...        ...
# 5339 -80.50146 -74.539389 -68.691773 -62.852965 -56.732048 -46.819963
# 5340 -80.50146 -74.946544 -69.958875 -65.247660 -60.515719 -54.716446
# 5341 -80.50146 -73.774451 -67.736315 -62.082204 -56.215736 -42.959873
# 5342 -80.50146 -73.900027 -68.270301 -63.185353 -58.049697 -48.268372
# 5343 -80.50146 -73.378675 -67.225861 -61.546816 -55.432824 -34.730714
#
#               6          7          8          9  ...        240        241  \
# 0     58.881427  53.758364  47.125866  41.577130  ...   8.093526  14.233536
# 1     46.183495  38.722102  28.631157  21.391622  ... -20.079739 -20.281990
# 2    -34.425259  34.122383  34.104529  26.182478  ... -86.948376 -86.950726
# 3     37.589030  41.796535  34.684865  28.438937  ...  -3.277842  -3.286780
# 4     57.832149  56.728695  53.429818  50.690608  ... -72.233335 -72.637223
# ...         ...        ...        ...        ...  ...        ...        ...
# 5339  34.833818  42.798500  37.444791  31.481640  ...  -4.694849  -4.892568
# 5340  -3.932562  52.140596  43.166902  34.589082  ... -79.789095 -79.794977
# 5341  46.504127  46.796831  37.706860  28.899318  ... -70.698642 -70.698645
# 5342  51.742084  53.797265  48.394088  42.877236  ... -73.107995 -73.117567
# 5343  39.336463  36.646365  29.345012  23.334629  ... -69.269274 -69.271532
#
#             242        243        244        245        246        247  \
# 0     17.883338  19.989153  21.158979  21.758281  22.005953  22.033896
# 1    -20.482540 -20.681184 -20.877728 -21.071989 -21.263794 -21.452982
# 2    -86.953046 -86.955339 -86.957603 -86.959839 -86.962048 -86.964230
# 3     -3.295097  -3.302810  -3.309936  -3.316489  -3.322486  -3.327945
# 4    -73.041176 -73.444834 -73.847821 -74.249752 -74.650228 -75.048845
# ...         ...        ...        ...        ...        ...        ...
# 5339  -5.092432  -5.294485  -5.498762  -5.705294  -5.914104  -6.125207
# 5340 -79.800800 -79.806565 -79.812273 -79.817925 -79.823521 -79.829062
# 5341 -70.698648 -70.698650 -70.698653 -70.698654 -70.698656 -70.698657
# 5342 -73.127077 -73.136526 -73.145914 -73.155241 -73.164507 -73.173711
# 5343 -69.273764 -69.275970 -69.278151 -69.280307 -69.282439 -69.284546
#
#             248        249
# 0     21.922441  21.721304
# 1    -21.639399 -21.822900
# 2    -86.966386 -86.968515
# 3     -3.332881  -3.337310
# 4    -75.445191 -75.838848
# ...         ...        ...
# 5339  -6.338606  -6.554296
# 5340 -79.834550 -79.839984
# 5341 -70.698658 -70.698658
# 5342 -73.182853 -73.191934
# 5343 -69.286629 -69.288688
#
# [5344 rows x 250 columns]

# %%
Y_data.shape
# Out:
# (4276, 76)

# %%
Total_Y_data.columns
# Out:
# Index(['V_myo(um3)', 'V_SR(um3)', 'V_myo_uL(uL)', 'V_SR_uL(uL)',
#        'i_NaK_max(uA)', 'K_m_K(mM)', 'K_m_Na(mM)', 'K_o(millimolar)',
#        'Na_o(millimolar)', 'Ca_TRPN_Max(mM)', 'g_Na(microS)', 'g_t(microS)',
#        'a_endo', 'b_endo', 'g_ss(microS)', 'g_K1(microS)', 'g_f(microS)',
#        'f_Na', 'g_B_Na(microS)', 'g_B_Ca(microS)', 'g_B_K(microS)',
#        'E_Ca(millivolt)', 'Ca_o(millimolar)', 'g_D(um3_per_ms)',
#        'J_R(um3_per_ms)', 'J_L(um3_per_ms)', 'N', 'K_mNa(mM)', 'K_mCa(mM)',
#        'eta', 'k_sat', 'g_NCX(mM_per_ms)', 'g_SERCA(mM_per_ms)', 'K_SERCA(mM)',
#        'g_pCa(mM_per_ms)', 'K_mpCa(mM)', 'g_CaB(mM_per_mV_ms)',
#        'g_SRl(per_ms)', 'k_CMDN(mM)', 'B_CMDN(mM)', 'k_on(per_mM_per_ms)',
#        'k_Ref_off(per_ms)', 'gamma_trpn', 'alpha_0(per_ms)',
#        'alpha_r1(per_ms)', 'alpha_r2(per_ms)', 'n_Rel', 'K_z', 'n_Hill',
#        'Ca_50ref(mM)', 'z_p', 'beta_1', 'beta_0', 'T_ref(N_per_mm2)',
#        'a in component Cross_Bridges', 'A_1', 'A_2', 'A_3', 'alpha_1(per_ms)',
#        'alpha_2(per_ms)', 'alpha_3(per_ms)', 'V_L(mV)', 'del_VL(mV)', 'phi_L',
#        't_L(ms)', 'tau_L(ms)', 'tau_R(ms)', 'phi_R', 'theta_R', 'K_RyR(mM)',
#        'K_L(mM)', 'a', 'b', 'c', 'd', 'tau_s_ss'],
#       dtype='object')

# %%
(Total_Y_data < 0).values.any()
# Out:
# True

# %% [markdown]
# ## Scaling and splitting the X_data and Y_data

# %%
scaler_y = StandardScaler().fit(Y_data)
scaler_x = StandardScaler().fit(X_data)

Y_data = scaler_y.transform(Y_data)
X_data = scaler_x.transform(X_data)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_data,Y_data,test_size=0.2,random_state=357, shuffle=True)

# %%
X_train.shape
# Out:
# (3420, 250)

# %%
#X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],1)

# %%
X_train = X_train.reshape(3420,250,1)

# %%
X_train.shape
# Out:
# (3420, 250, 1)

# %%
## Model Train CNN

# %%
def r_square(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
import tensorflow as tf

callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=5,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_r_square', factor=0.1,
                              patience=5, min_lr=0.00001)

callbacks = [callback,reduce_lr]

# %%
from keras.layers import Conv1D,MaxPooling1D,GlobalAveragePooling1D,Dropout,Dense,BatchNormalization

# %%
model1 = Sequential()
model1.add(Conv1D(128, 10, padding="same",activation='tanh', input_shape=(X_train.shape[1], 1)))
model1.add(Conv1D(128, 10, padding="same",activation='tanh'))

model1.add(BatchNormalization())
model1.add(MaxPooling1D(5))
model1.add(Conv1D(128, 10, padding="same",activation='tanh'))

model1.add(Conv1D(128, 10, padding="same", activation='tanh'))
model1.add(BatchNormalization())
model1.add(GlobalAveragePooling1D())

model1.add(Dense(500, activation='tanh'))
model1.add(Dropout(rate=0.5))
model1.add(Dense(200, activation='tanh'))
model1.add(Dense(76,activation='tanh'))
print(model1.summary())
model1.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=[r_square])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 250, 128)          1408
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 250, 128)          163968
# _________________________________________________________________
# batch_normalization (BatchNo (None, 250, 128)          512
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 50, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 50, 128)           163968
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 50, 128)           163968
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 128)           512
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 500)               64500
# _________________________________________________________________
# dropout (Dropout)            (None, 500)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               100200
# _________________________________________________________________
# dense_2 (Dense)              (None, 76)                15276
# =================================================================
# Total params: 674,312
# Trainable params: 673,800
# Non-trainable params: 512
# _________________________________________________________________
# None

# %%
history1 = model1.fit(X_train, y_train,
                  epochs=20,
                  batch_size=64,
                  validation_data=(X_val.reshape(X_val.shape[0],X_val.shape[1],1), y_val), callbacks=[callbacks])
# Out:
# Epoch 1/20
# 54/54 [==============================] - 14s 267ms/step - loss: 1.0869 - r_square: -0.0870 - val_loss: 1.0067 - val_r_square: -0.0062
# Epoch 2/20
# 54/54 [==============================] - 13s 246ms/step - loss: 1.0209 - r_square: -0.0215 - val_loss: 1.0028 - val_r_square: -0.0021
# Epoch 3/20
# 54/54 [==============================] - 14s 261ms/step - loss: 1.0087 - r_square: -0.0090 - val_loss: 0.9988 - val_r_square: 0.0012
# Epoch 4/20
# 54/54 [==============================] - 14s 261ms/step - loss: 0.9968 - r_square: 0.0029 - val_loss: 0.9951 - val_r_square: 0.0051
# Epoch 5/20
# 54/54 [==============================] - 14s 261ms/step - loss: 0.9905 - r_square: 0.0092 - val_loss: 0.9896 - val_r_square: 0.0108
# Epoch 6/20
# 54/54 [==============================] - 14s 261ms/step - loss: 0.9840 - r_square: 0.0156 - val_loss: 1.0057 - val_r_square: -0.0055
# Epoch 7/20
# 54/54 [==============================] - 14s 261ms/step - loss: 0.9718 - r_square: 0.0278 - val_loss: 0.9765 - val_r_square: 0.0238
# Epoch 8/20
# 54/54 [==============================] - 14s 260ms/step - loss: 0.9674 - r_square: 0.0321 - val_loss: 0.9727 - val_r_square: 0.0276
# Epoch 9/20
# 54/54 [==============================] - 14s 261ms/step - loss: 0.9656 - r_square: 0.0339 - val_loss: 0.9703 - val_r_square: 0.0302
# Epoch 10/20
# 54/54 [==============================] - 14s 262ms/step - loss: 0.9643 - r_square: 0.0351 - val_loss: 0.9684 - val_r_square: 0.0321
# Epoch 11/20
# 54/54 [==============================] - 14s 262ms/step - loss: 0.9632 - r_square: 0.0364 - val_loss: 0.9672 - val_r_square: 0.0332
# Epoch 12/20
# 54/54 [==============================] - 14s 261ms/step - loss: 0.9619 - r_square: 0.0377 - val_loss: 0.9646 - val_r_square: 0.0359
# Epoch 13/20
# 54/54 [==============================] - 15s 284ms/step - loss: 0.9608 - r_square: 0.0388 - val_loss: 0.9635 - val_r_square: 0.0370
# Epoch 14/20
# 54/54 [==============================] - 14s 263ms/step - loss: 0.9607 - r_square: 0.0389 - val_loss: 0.9626 - val_r_square: 0.0379
# Epoch 15/20
# 54/54 [==============================] - 14s 263ms/step - loss: 0.9603 - r_square: 0.0393 - val_loss: 0.9623 - val_r_square: 0.0381
# Epoch 16/20
# 54/54 [==============================] - 14s 263ms/step - loss: 0.9604 - r_square: 0.0390 - val_loss: 0.9621 - val_r_square: 0.0384
# Epoch 17/20
# 54/54 [==============================] - 14s 262ms/step - loss: 0.9600 - r_square: 0.0395 - val_loss: 0.9620 - val_r_square: 0.0385
# Epoch 18/20
# 54/54 [==============================] - 14s 263ms/step - loss: 0.9602 - r_square: 0.0394 - val_loss: 0.9618 - val_r_square: 0.0387
# Epoch 19/20
# 54/54 [==============================] - 14s 263ms/step - loss: 0.9601 - r_square: 0.0395 - val_loss: 0.9617 - val_r_square: 0.0388
# Epoch 20/20
# 54/54 [==============================] - 14s 264ms/step - loss: 0.9594 - r_square: 0.0402 - val_loss: 0.9615 - val_r_square: 0.0389

# %%
Y_test = scaler_y.transform(Y_test)
X_test = scaler_x.transform(X_test)

# %%
# names = ['V_myo(um3)', 'N', 'g_D(um3_per_ms)', 'K_L(mM)', 'V_myo_uL(uL)',
#        'del_VL(mV)', 'tau_L(ms)', 'phi_L', 'g_t(microS)', 'K_RyR(mM)']

# %%
names= ['V_myo(um3)', 'V_SR(um3)', 'V_myo_uL(uL)', 'V_SR_uL(uL)',
       'i_NaK_max(uA)', 'K_m_K(mM)', 'K_m_Na(mM)', 'K_o(millimolar)',
       'Na_o(millimolar)', 'Ca_TRPN_Max(mM)', 'g_Na(microS)', 'g_t(microS)',
       'a_endo', 'b_endo', 'g_ss(microS)', 'g_K1(microS)', 'g_f(microS)',
       'f_Na', 'g_B_Na(microS)', 'g_B_Ca(microS)', 'g_B_K(microS)',
       'E_Ca(millivolt)', 'Ca_o(millimolar)', 'g_D(um3_per_ms)',
       'J_R(um3_per_ms)', 'J_L(um3_per_ms)', 'N', 'K_mNa(mM)', 'K_mCa(mM)',
       'eta', 'k_sat', 'g_NCX(mM_per_ms)', 'g_SERCA(mM_per_ms)', 'K_SERCA(mM)',
       'g_pCa(mM_per_ms)', 'K_mpCa(mM)', 'g_CaB(mM_per_mV_ms)',
       'g_SRl(per_ms)', 'k_CMDN(mM)', 'B_CMDN(mM)', 'k_on(per_mM_per_ms)',
       'k_Ref_off(per_ms)', 'gamma_trpn', 'alpha_0(per_ms)',
       'alpha_r1(per_ms)', 'alpha_r2(per_ms)', 'n_Rel', 'K_z', 'n_Hill',
       'Ca_50ref(mM)', 'z_p', 'beta_1', 'beta_0', 'T_ref(N_per_mm2)',
       'a in component Cross_Bridges', 'A_1', 'A_2', 'A_3', 'alpha_1(per_ms)',
       'alpha_2(per_ms)', 'alpha_3(per_ms)', 'V_L(mV)', 'del_VL(mV)', 'phi_L',
       't_L(ms)', 'tau_L(ms)', 'tau_R(ms)', 'phi_R', 'theta_R', 'K_RyR(mM)',
       'K_L(mM)', 'a', 'b', 'c', 'd', 'tau_s_ss']

# %%
pd.set_option('display.max_rows', 500)

# %%
results_df = pd.DataFrame()
ypred1 = model1.predict(X_test.reshape(X_test.shape[0],X_test.shape[1],1))

extra_results_df = pd.DataFrame([r2_score(Y_test[:,i],ypred1[:,i]) for i in range(len(names))],index=names,columns=['r2_score'])
results_df = pd.concat([results_df,extra_results_df],axis=1)
results_df
# Out:
#                               r2_score
# V_myo(um3)                    0.144568
# V_SR(um3)                    -0.000648
# V_myo_uL(uL)                  0.103789
# V_SR_uL(uL)                   0.023357
# i_NaK_max(uA)                 0.004632
# K_m_K(mM)                    -0.001231
# K_m_Na(mM)                    0.010723
# K_o(millimolar)               0.617084
# Na_o(millimolar)              0.178280
# Ca_TRPN_Max(mM)               0.029070
# g_Na(microS)                  0.053763
# g_t(microS)                   0.372098
# a_endo                        0.155090
# b_endo                        0.035314
# g_ss(microS)                  0.004606
# g_K1(microS)                  0.079732
# g_f(microS)                   0.003153
# f_Na                          0.002415
# g_B_Na(microS)                0.001918
# g_B_Ca(microS)               -0.005623
# g_B_K(microS)                -0.008792
# E_Ca(millivolt)              -0.003173
# Ca_o(millimolar)              0.056929
# g_D(um3_per_ms)               0.192579
# J_R(um3_per_ms)               0.004924
# J_L(um3_per_ms)               0.021696
# N                             0.131502
# K_mNa(mM)                     0.008072
# K_mCa(mM)                     0.003398
# eta                           0.003875
# k_sat                        -0.005321
# g_NCX(mM_per_ms)              0.008739
# g_SERCA(mM_per_ms)            0.037115
# K_SERCA(mM)                   0.001208
# g_pCa(mM_per_ms)              0.004328
# K_mpCa(mM)                   -0.004973
# g_CaB(mM_per_mV_ms)           0.005451
# g_SRl(per_ms)                -0.003558
# k_CMDN(mM)                    0.008320
# B_CMDN(mM)                    0.002969
# k_on(per_mM_per_ms)           0.009477
# k_Ref_off(per_ms)             0.024307
# gamma_trpn                   -0.004238
# alpha_0(per_ms)               0.006386
# alpha_r1(per_ms)             -0.002592
# alpha_r2(per_ms)             -0.001304
# n_Rel                        -0.001490
# K_z                          -0.001280
# n_Hill                       -0.001670
# Ca_50ref(mM)                  0.001145
# z_p                          -0.003407
# beta_1                       -0.003203
# beta_0                       -0.001269
# T_ref(N_per_mm2)             -0.003507
# a in component Cross_Bridges -0.004419
# A_1                          -0.002636
# A_2                          -0.001979
# A_3                          -0.002055
# alpha_1(per_ms)              -0.007582
# alpha_2(per_ms)              -0.003263
# alpha_3(per_ms)               0.000058
# V_L(mV)                       0.003190
# del_VL(mV)                    0.201817
# phi_L                         0.024618
# t_L(ms)                      -0.004860
# tau_L(ms)                     0.094097
# tau_R(ms)                     0.000077
# phi_R                         0.019665
# theta_R                      -0.005364
# K_RyR(mM)                     0.109659
# K_L(mM)                       0.108346
# a                            -0.005098
# b                            -0.002947
# c                            -0.001506
# d                            -0.005191
# tau_s_ss                     -0.002886

# %%
r2_score(Y_test, ypred1)
# Out:
# 0.03692726822270481
